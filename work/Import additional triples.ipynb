# %%
from SPARQLWrapper import SPARQLWrapper, RDFXML, JSON
import requests
import time

# Basic configuration
endpoint = "https://wb.pcp-on-web.de/store-oker/research/"
#query_path = "https://raw.githubusercontent.com/pcp-on-web/data-import/main/Import-Catalogus-Professorum-Lipsiensium/"


# This function counts the genrated tripples of the research ontolgy (data:)
def count_triples(endpoint,graph) :
    #count number of exiting triples
    sparql = SPARQLWrapper(endpoint+'sparql')
    sparql.setQuery('SELECT (COUNT(*) as ?Triples) FROM '+graph+' WHERE { ?s ?p ?o}')
    sparql.setReturnFormat(JSON)
    json_results = sparql.query().convert()
    return json_results['results']['bindings'][0]['Triples']['value']
    

# This function executes a sparql construct query and imports the data to the research ontolgy (data:)
def query_sparql(query, endpoint) :
    start_time = time.time()
    
    data_graph="leer"
    text_lines = query.split("\n")
    info = text_lines[1]+"\n"+text_lines[2]
    for line in text_lines:
        if line.find("PREFIX ")==0:
           p = 0
           p = line.find("PREFIX data:") 
           if p == 0 :
                data_graph = line[line.find("<"):]
            
    start_count = count_triples(endpoint,data_graph)
    
    sparql = SPARQLWrapper(endpoint)
    sparql.setQuery(query)
    sparql.method = 'POST'
    sparql.query()

    end_count = count_triples(endpoint,data_graph)

    output =  "\n"+info+"\n"+start_count + "-" + end_count + "\n--- " + str(time.time() - start_time) + " seconds ---"
    return output

# %%
data = """
# Delete triples
#-----

PREFIX rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#>
PREFIX pcp: <http://pcp-on-web.de/ontology#>
PREFIX data: <http://data.pcp-on-web.de/v.1/>
PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#>
PREFIX xsd: <http://www.w3.org/2001/XMLSchema#>
PREFIX cpm: <http://catalogus-professorum.org/cpm/2/>
PREFIX cpl: <http://catalogus-professorum.org/lipsiensium/>


DELETE DATA { GRAPH data: {

  <http://data.pcp-on-web.de/v.1/lipsiensium/professor/crusius_1412> pcp:hasStageOfLife <http://data.pcp-on-web.de/v.1/lipsiensium/period-of-life/career-karriere_8526> .

  }
}
""";

print(query_sparql(data,endpoint))
# Out:
# # Delete triples
# #-----
# 47988-47987
# --- 0.2905118465423584 seconds ---

# %%
data = """
# Add triples
#-----

PREFIX rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#>
PREFIX pcp: <http://pcp-on-web.de/ontology#>
PREFIX data: <http://data.pcp-on-web.de/v.1/>
PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#>
PREFIX xsd: <http://www.w3.org/2001/XMLSchema#>
PREFIX cpm: <http://catalogus-professorum.org/cpm/2/>
PREFIX cpl: <http://catalogus-professorum.org/lipsiensium/>


INSERT DATA { GRAPH data: {

# Theologische Fakultät der Universität Leipzig
<http://data.pcp-on-web.de/v.1/lipsiensium/body/faculty-theologischefakultaet> rdf:type pcp:FacultyOfTheology.  

# Philosophische Fakultät der Universität Leipzig (bis 1920)
<http://data.pcp-on-web.de/v.1/lipsiensium/body/faculty-philosophischefakultaet> rdf:type pcp:FacultyOfPhilosophy.  

# Artistenfakultät !!*!! http://data.pcp-on-web.de/v.1/lipsiensium/body/faculty-artistenfakultaet> rdf:type pcp:FacultyOfPhilosophy.  

# Juristenfakultät der Universität Leipzig
<http://data.pcp-on-web.de/v.1/lipsiensium/body/faculty-juristenfakultaet> rdf:type pcp:FacultyOfLaw.  

# Medizinische Fakultät der Universität Leipzig
<http://data.pcp-on-web.de/v.1/lipsiensium/body/faculty-medizinischefakultaet> rdf:type pcp:FacultyOfMedicine.  

# Universitas Ottoniano-Fridericiana Bambergensis, Juristische Fakultät
<http://data.pcp-on-web.de/v.1/bamberg/e9b1f2e1-693c-4227-a28d-9ad19aa55f9d> rdf:type pcp:FacultyOfLaw.  

# Universitas Ottoniano-Fridericiana Bambergensis, Theologische Fakultät
<http://data.pcp-on-web.de/v.1/bamberg/15e4d747-cd75-4f61-8e7a-190c7822ed28> rdf:type pcp:FacultyOfTheology.  

# Universitas Ottoniano-Fridericiana Bambergensis, Philosophische Fakultät
<http://data.pcp-on-web.de/v.1/bamberg/a9e18f98-a9a4-4705-8892-44b38b276e71> rdf:type pcp:FacultyOfPhilosophy.  

# Lyzeum Bamberg, Theologische Sektion
<http://data.pcp-on-web.de/v.1/bamberg/01f2ba33-725b-45c9-a800-e6304f5bc561> rdf:type pcp:FacultyOfTheology.  

# Universitas Ottoniano-Fridericiana Bambergensis, Medizinische Fakultät
<http://data.pcp-on-web.de/v.1/bamberg/62c05ffa-cb43-4d2a-8ac7-5fe9cf402fd2> rdf:type pcp:FacultyOfMedicine.  

# Albert-Ludwigs-Universität Freiburg, Philosophische Fakultät
<http://data.pcp-on-web.de/v.1/bamberg/8c9ad71c-5880-4e5b-a878-a5ebdc0c1e6c> rdf:type pcp:FacultyOfPhilosophy.  

# Lyzeum Bamberg, Philosophische Sektion
<http://data.pcp-on-web.de/v.1/bamberg/2fc375bc-b11c-4d4a-82ef-affd9b39cb94> rdf:type pcp:FacultyOfPhilosophy.  

# Universität Helmstedt Phil Fakultät
<http://data.pcp-on-web.de/v.1/UniversitaetHelmstedt-Phil> rdf:type pcp:FacultyOfPhilosophy.  

# Universität Helmstedt Jur. Fakultät
<http://data.pcp-on-web.de/v.1/UniversitaetHelmstedt-Jur> rdf:type pcp:FacultyOfLaw.  

# Universität Helmstedt Med. Fakultät
<http://data.pcp-on-web.de/v.1/UniversitaetHelmstedt-Med> rdf:type pcp:FacultyOfMedicine.  

# Universität Altdorf Nürnberg Med. Fakultät
<http://data.pcp-on-web.de/v.1/UniversitatAltdorfNurnberg-Med> rdf:type pcp:FacultyOfMedicine.  

# Universität Alma Mater Viadrina Med. Fakultät
<http://data.pcp-on-web.de/v.1/UniversitatAlmaMaterViadrina-Med> rdf:type pcp:FacultyOfMedicine.  

# Universität Leipzig Phil. Fakultät
<http://data.pcp-on-web.de/v.1/UniversitatLeipzig-Phil> rdf:type pcp:FacultyOfPhilosophy.  

# Universität Erlangen Med. Fakultät
<http://data.pcp-on-web.de/v.1/UniversitatErlangen-Med> rdf:type pcp:FacultyOfMedicine.  

# Universität Marburg Med. Fakultät
<http://data.pcp-on-web.de/v.1/UniversitatMarburg-Med> rdf:type pcp:FacultyOfMedicine.  

# Universität Helmstedt Theol. Fakultät
<http://data.pcp-on-web.de/v.1/UniversitaetHelmstedt-Theol> rdf:type pcp:FacultyOfTheology.  

# Universität Wittenberg unb. Fakultät
<http://data.pcp-on-web.de/v.1/UniversitatWittenberg-unb> rdf:type pcp:Faculty.  

# Universität Gießen Med. Fakultät
<http://data.pcp-on-web.de/v.1/UniversitatGiessen-Med> rdf:type pcp:FacultyOfMedicine.  

# Københavns Universitet Theol. Fakultät
<http://data.pcp-on-web.de/v.1/KbenhavnsUniversitet-Theol> rdf:type pcp:FacultyOfTheology.  

# Universität Alma Mater Viadrina Phil. Fakultät
<http://data.pcp-on-web.de/v.1/UniversitatAlmaMaterViadrina-Phil> rdf:type pcp:FacultyOfPhilosophy.  

# Universität Halle (Saale) Phil. Fakultät
<http://data.pcp-on-web.de/v.1/UniversitatHalleSaale-Phil> rdf:type pcp:FacultyOfPhilosophy.  

# Universität Rostock Phil. Fakultät
<http://data.pcp-on-web.de/v.1/UniversitatRostock-Phil> rdf:type pcp:FacultyOfPhilosophy.  

# Universität Wittenberg Med. Fakultät
<http://data.pcp-on-web.de/v.1/UniversitatWittenberg-Med> rdf:type pcp:FacultyOfMedicine.  

# Universität Göttingen Med. Fakultät
<http://data.pcp-on-web.de/v.1/UniversitatGottingen-Med> rdf:type pcp:FacultyOfMedicine.  

# Hohe Schule Jena Phil. Fakultät
<http://data.pcp-on-web.de/v.1/HoheSchuleJena-Phil> rdf:type pcp:FacultyOfPhilosophy.  

# Hohe Schule Jena Theol. Fakultät
<http://data.pcp-on-web.de/v.1/HoheSchuleJena-Theol> rdf:type pcp:FacultyOfTheology.  

# Universität Altdorf Nürnberg Theol. Fakultät
<http://data.pcp-on-web.de/v.1/UniversitatAltdorfNurnberg-Theol> rdf:type pcp:FacultyOfTheology.  

# Universität Marburg Jur. Fakultät
<http://data.pcp-on-web.de/v.1/UniversitatMarburg-Jur> rdf:type pcp:FacultyOfLaw.  

# Universität Heidelberg Jur. Fakultät
<http://data.pcp-on-web.de/v.1/UniversitatHeidelberg-Jur> rdf:type pcp:FacultyOfLaw.  

# Rijksuniversiteit Groningen Med. Fakultät
<http://data.pcp-on-web.de/v.1/RijksuniversiteitGroningen-Med> rdf:type pcp:FacultyOfMedicine.  

# Universität Halle (Saale) Jur. Fakultät
<http://data.pcp-on-web.de/v.1/UniversitatHalleSaale-Jur> rdf:type pcp:FacultyOfLaw.  

# Universität Erlangen Jur. Fakultät
<http://data.pcp-on-web.de/v.1/UniversitatErlangen-Jur> rdf:type pcp:FacultyOfLaw.  

# Universität Alma Mater Viadrina Theol. Fakultät
<http://data.pcp-on-web.de/v.1/UniversitatAlmaMaterViadrina-Theol> rdf:type pcp:FacultyOfTheology.  

# Universität Heidelberg Theol. Fakultät
<http://data.pcp-on-web.de/v.1/UniversitatHeidelberg-Theol> rdf:type pcp:FacultyOfTheology.  

# Universität Königsberg Theol. Fakultät
<http://data.pcp-on-web.de/v.1/UniversitatKonigsberg-Theol> rdf:type pcp:FacultyOfTheology.  

# Universität Rinteln Phil. Fakultät
<http://data.pcp-on-web.de/v.1/UniversitatRinteln-Phil> rdf:type pcp:FacultyOfPhilosophy.  

# Universität Wittenberg Jur. Fakultät
<http://data.pcp-on-web.de/v.1/UniversitatWittenberg-Jur> rdf:type pcp:FacultyOfLaw.  

# Universität Kiel Phil. Fakultät
<http://data.pcp-on-web.de/v.1/UniversitatKiel-Phil> rdf:type pcp:FacultyOfPhilosophy.  

# Universität Göttingen Theol. Fakultät
<http://data.pcp-on-web.de/v.1/UniversitatGottingen-Theol> rdf:type pcp:FacultyOfTheology.  

# Universität Rinteln Theol. Fakultät
<http://data.pcp-on-web.de/v.1/UniversitatRinteln-Theol> rdf:type pcp:FacultyOfTheology.  

# Universität Kiel Theol. Fakultät
<http://data.pcp-on-web.de/v.1/UniversitatKiel-Theol> rdf:type pcp:FacultyOfTheology.  

# Universität Freiburg Breisgau Jur. Fakultät
<http://data.pcp-on-web.de/v.1/UniversitatFreiburgBreisgau-Jur> rdf:type pcp:FacultyOfLaw.  

# Ratsgymnasium Stadthagen Med. Fakultät
<http://data.pcp-on-web.de/v.1/RatsgymnasiumStadthagen-Med> rdf:type pcp:FacultyOfMedicine.  

# Hohe Schule Jena Jur. Fakultät
<http://data.pcp-on-web.de/v.1/HoheSchuleJena-Jur> rdf:type pcp:FacultyOfLaw.  

# Universität Königsberg Phil. Fakultät
<http://data.pcp-on-web.de/v.1/UniversitatKonigsberg-Phil> rdf:type pcp:FacultyOfPhilosophy.  

# Universität Kiel Jur. Fakultät
<http://data.pcp-on-web.de/v.1/UniversitatKiel-Jur> rdf:type pcp:FacultyOfLaw.  

# Universität Königsberg Med. Fakultät
<http://data.pcp-on-web.de/v.1/UniversitatKonigsberg-Med> rdf:type pcp:FacultyOfMedicine.  

# Jesuitenkolleg Hildesheim Phil. Fakultät
<http://data.pcp-on-web.de/v.1/JesuitenkollegHildesheim-Phil> rdf:type pcp:FacultyOfPhilosophy.  

# Universität Kiel Med. Fakultät
<http://data.pcp-on-web.de/v.1/UniversitatKiel-Med> rdf:type pcp:FacultyOfMedicine.  

# Universität Tübingen Jur. Fakultät
<http://data.pcp-on-web.de/v.1/UniversitatTubingen-Jur> rdf:type pcp:FacultyOfLaw.  

# Universität Greifswald Theol. Fakultät
<http://data.pcp-on-web.de/v.1/UniversitatGreifswald-Theol> rdf:type pcp:FacultyOfTheology.  

# Universität Göttingen Phil. Fakultät
<http://data.pcp-on-web.de/v.1/UniversitatGottingen-Phil> rdf:type pcp:FacultyOfPhilosophy.  

# Universität Wittenberg Phil. Fakultät
<http://data.pcp-on-web.de/v.1/UniversitatWittenberg-Phil> rdf:type pcp:FacultyOfPhilosophy.  

# Universität Rostock Theol. Fakultät
<http://data.pcp-on-web.de/v.1/UniversitatRostock-Theol> rdf:type pcp:FacultyOfTheology.  

# Universität Erlangen Phil. Fakultät
<http://data.pcp-on-web.de/v.1/UniversitatErlangen-Phil> rdf:type pcp:FacultyOfPhilosophy.  

# Universität Rinteln Theol. / Phil. Fakultät
<http://data.pcp-on-web.de/v.1/UniversitatRinteln-TheolPhil> rdf:type pcp:FacultyOfTheology.  

# Universität Bonn Jur. Fakultät
<http://data.pcp-on-web.de/v.1/UniversitatBonn-Jur> rdf:type pcp:FacultyOfLaw.  

# Universität Helmstedt Phil. / Jur. Fakultät
<http://data.pcp-on-web.de/v.1/UniversitaetHelmstedt-PhilJur> rdf:type pcp:FacultyOfPhilosophy.  

# Universität Halle (Saale) Med. / Phil. Fakultät
<http://data.pcp-on-web.de/v.1/UniversitatHalleSaale-MedPhil> rdf:type pcp:FacultyOfMedicine.  

# Universität Halle (Saale) Med. Fakultät
<http://data.pcp-on-web.de/v.1/UniversitatHalleSaale-Med> rdf:type pcp:FacultyOfMedicine.  

# Universität Leipzig Jur. Fakultät
<http://data.pcp-on-web.de/v.1/UniversitatLeipzig-Jur> rdf:type pcp:FacultyOfLaw.  

# Universität Göttingen Jur. Fakultät
<http://data.pcp-on-web.de/v.1/UniversitatGottingen-Jur> rdf:type pcp:FacultyOfLaw.  

  }
}
""";

print(query_sparql(data,endpoint))
# Out:
# # Add triples
# #-----
# 47987-48052
# --- 0.2981693744659424 seconds ---

# %%
data = """
# Delete type pcp:Faculty
#-----

PREFIX rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#>
PREFIX pcp: <http://pcp-on-web.de/ontology#>
PREFIX data: <http://data.pcp-on-web.de/v.1/>
PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#>
PREFIX xsd: <http://www.w3.org/2001/XMLSchema#>
PREFIX cpm: <http://catalogus-professorum.org/cpm/2/>
PREFIX cpl: <http://catalogus-professorum.org/lipsiensium/>


DELETE DATA { GRAPH data: {

data:HoheSchuleJena-Phil rdf:type pcp:Faculty .
<http://data.pcp-on-web.de/v.1/bamberg/01f2ba33-725b-45c9-a800-e6304f5bc561> rdf:type pcp:Faculty .
data:UniversitatAltdorfNurnberg-Theol rdf:type pcp:Faculty .
data:UniversitatRinteln-TheolPhil rdf:type pcp:Faculty .
data:UniversitatGottingen-Theol rdf:type pcp:Faculty .
data:UniversitatMarburg-Med rdf:type pcp:Faculty .
data:UniversitatRostock-Phil rdf:type pcp:Faculty .
<http://data.pcp-on-web.de/v.1/bamberg/a9e18f98-a9a4-4705-8892-44b38b276e71> rdf:type pcp:Faculty .
data:UniversitatErlangen-Med rdf:type pcp:Faculty .
data:UniversitatKonigsberg-Theol rdf:type pcp:Faculty .
data:UniversitatHalleSaale-MedPhil rdf:type pcp:Faculty .
data:UniversitatLeipzig-Jur rdf:type pcp:Faculty .
data:UniversitatErlangen-Phil rdf:type pcp:Faculty .
<http://data.pcp-on-web.de/v.1/bamberg/62c05ffa-cb43-4d2a-8ac7-5fe9cf402fd2> rdf:type pcp:Faculty .
data:UniversitatRostock-Theol rdf:type pcp:Faculty .
data:UniversitaetHelmstedt-Jur rdf:type pcp:Faculty .
data:UniversitatKonigsberg-Med rdf:type pcp:Faculty .
data:UniversitatBonn-Jur rdf:type pcp:Faculty .
data:UniversitatKiel-Med rdf:type pcp:Faculty .
<http://data.pcp-on-web.de/v.1/bamberg/e9b1f2e1-693c-4227-a28d-9ad19aa55f9d> rdf:type pcp:Faculty .
<http://data.pcp-on-web.de/v.1/lipsiensium/body/faculty-medizinischefakultaet> rdf:type pcp:Faculty .
data:UniversitatAlmaMaterViadrina-Phil rdf:type pcp:Faculty .
data:UniversitatRinteln-Theol rdf:type pcp:Faculty .
data:UniversitatWittenberg-Med rdf:type pcp:Faculty .
data:UniversitatTubingen-Jur rdf:type pcp:Faculty .
data:UniversitatLeipzig-Phil rdf:type pcp:Faculty .
data:JesuitenkollegHildesheim-Phil rdf:type pcp:Faculty .
<http://data.pcp-on-web.de/v.1/bamberg/8c9ad71c-5880-4e5b-a878-a5ebdc0c1e6c> rdf:type pcp:Faculty .
data:UniversitatGottingen-Phil rdf:type pcp:Faculty .
data:UniversitaetHelmstedt-PhilJur rdf:type pcp:Faculty .
data:UniversitatRinteln-Phil rdf:type pcp:Faculty .
<http://data.pcp-on-web.de/v.1/bamberg/2fc375bc-b11c-4d4a-82ef-affd9b39cb94> rdf:type pcp:Faculty .
data:UniversitatGottingen-Med rdf:type pcp:Faculty .
data:UniversitatHalleSaale-Med rdf:type pcp:Faculty .
data:UniversitatFreiburgBreisgau-Jur rdf:type pcp:Faculty .
data:UniversitatMarburg-Jur rdf:type pcp:Faculty .
data:UniversitatGiessen-Med rdf:type pcp:Faculty .
<http://data.pcp-on-web.de/v.1/lipsiensium/body/faculty-fakultaetphysikgeo> rdf:type pcp:Faculty .
<http://data.pcp-on-web.de/v.1/lipsiensium/body/faculty-juristenfakultaet> rdf:type pcp:Faculty .
<http://data.pcp-on-web.de/v.1/lipsiensium/body/faculty-fakultaetmathnat> rdf:type pcp:Faculty .
data:UniversitatErlangen-Jur rdf:type pcp:Faculty .
data:UniversitatAlmaMaterViadrina-Med rdf:type pcp:Faculty .
data:UniversitatKiel-Theol rdf:type pcp:Faculty .
data:KbenhavnsUniversitet-Theol rdf:type pcp:Faculty .
data:RijksuniversiteitGroningen-Med rdf:type pcp:Faculty .
<http://data.pcp-on-web.de/v.1/bamberg/15e4d747-cd75-4f61-8e7a-190c7822ed28> rdf:type pcp:Faculty .
data:RatsgymnasiumStadthagen-Med rdf:type pcp:Faculty .
data:UniversitatKiel-Jur rdf:type pcp:Faculty .
data:UniversitatAltdorfNurnberg-Med rdf:type pcp:Faculty .
data:UniversitaetHelmstedt-Theol rdf:type pcp:Faculty .
<http://data.pcp-on-web.de/v.1/lipsiensium/body/faculty-philosophischefakultaet> rdf:type pcp:Faculty .
data:UniversitatKiel-Phil rdf:type pcp:Faculty .
<http://data.pcp-on-web.de/v.1/lipsiensium/body/faculty-artistenfakultaet> rdf:type pcp:Faculty .
data:UniversitatAlmaMaterViadrina-Theol rdf:type pcp:Faculty .
data:UniversitatWittenberg-Jur rdf:type pcp:Faculty .
data:UniversitatHalleSaale-Phil rdf:type pcp:Faculty .
data:UniversitaetHelmstedt-Med rdf:type pcp:Faculty .
<http://data.pcp-on-web.de/v.1/lipsiensium/body/faculty-theologischefakultaet> rdf:type pcp:Faculty .
data:UniversitaetHelmstedt-Phil rdf:type pcp:Faculty .
data:HoheSchuleJena-Theol rdf:type pcp:Faculty .
data:UniversitatGreifswald-Theol rdf:type pcp:Faculty .
data:HoheSchuleJena-Jur rdf:type pcp:Faculty .
data:UniversitatWittenberg-Phil rdf:type pcp:Faculty .
data:UniversitatHeidelberg-Theol rdf:type pcp:Faculty .
data:UniversitatGottingen-Jur rdf:type pcp:Faculty .
data:UniversitatKonigsberg-Phil rdf:type pcp:Faculty .
data:UniversitatHeidelberg-Jur rdf:type pcp:Faculty .
data:UniversitatHalleSaale-Jur rdf:type pcp:Faculty .


#Doppelte labels entfernen

<http://data.pcp-on-web.de/v.1/lipsiensium/body/faculty-theologischefakultaet> rdfs:label "Theologische Fakultät".
<http://data.pcp-on-web.de/v.1/lipsiensium/body/faculty-philosophischefakultaet> rdfs:label "Philosophische Fakultät". 
<http://data.pcp-on-web.de/v.1/lipsiensium/body/faculty-juristenfakultaet> rdfs:label "Juristenfakultät". 
<http://data.pcp-on-web.de/v.1/lipsiensium/body/faculty-fakultaetmathnat> rdfs:label "Fakultät für Mathematik und Naturwissenschaften". 
<http://data.pcp-on-web.de/v.1/lipsiensium/body/faculty-fakultaetmathnat> rdfs:label "Fakultät für Mathematik und Naturwissenschaften (1990-1993)". 
<http://data.pcp-on-web.de/v.1/lipsiensium/body/faculty-fakultaetphysikgeo> rdfs:label "Fakultät für Physik und Geowissenschaften". 
<http://data.pcp-on-web.de/v.1/lipsiensium/body/faculty-fakultaetphysikgeo> rdfs:label "Fakultät für Physik und Geowissenschaften der Universität Leipzig (seit 1994)". 
<http://data.pcp-on-web.de/v.1/UniversitaetHelmstedt-Phil> rdfs:label "Universität Helmstedt Phil Fakultät". 


  }
}
""";

print(query_sparql(data,endpoint))
# Out:
# # Delete type pcp:Faculty
# #-----
# 48052-47976
# --- 0.30505919456481934 seconds ---
